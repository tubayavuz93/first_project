# %%
print("Merhaba, İGÜ - İSTKA!") # print ekrana çıktı veren bir koddur.
# Out:
# Merhaba, İGÜ - İSTKA!

# %% [markdown]
# Python programlam dilinde print komutu ekrandan kullanıcıya bilgi veren bir koddur.
# 06.08.2024-Veri Yapıları ve Algoritmalar dersi ilk kodlama çıktısıdır.
# İGÜ İSTKA SİBER AKADEMİ MERKEZİ

# %%
import sys #python proglama dilinde yazılıma kütüphane eklemeye yarayan bir koddur.
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive    #google colab- drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os  #os kütüphanesi
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pwd #bize kodun çıktısını dosya yolu olarak veren kod blogudur
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA
